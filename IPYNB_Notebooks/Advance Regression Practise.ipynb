# %%
mer_level=pd.read_csv('/home/pkumari/Downloads/Hacker.txt',sep="\t",skiprows=1,header=None)
mer_level.columns=['day_time','level']

# %%
mer_level['day_time']=pd.to_datetime(mer_level['day_time'])

# %%
mer_level
# Out:
#                day_time       level
# 0   2012-01-03 16:00:00      333.74
# 1   2012-01-04 16:00:00      334.79
# 2   2012-01-05 16:00:00      331.65
# 3   2012-01-06 16:00:00      329.67
# 4   2012-01-09 16:00:00      323.18
# 5   2012-01-10 16:00:00      316.58
# 6   2012-01-11 16:00:00      314.38
# 7   2012-01-12 16:00:00      316.13
# 8   2012-01-13 16:00:00      313.16
# 9   2012-01-17 16:00:00      315.67
# 10  2012-01-18 16:00:00      316.68
# 11  2012-01-19 16:00:00      320.17
# 12  2012-01-20 16:00:00       295.2
# 13  2012-01-23 16:00:00      294.04
# 14  2012-01-24 16:00:00      293.55
# 15  2012-01-25 16:00:00      289.07
# 16  2012-01-26 16:00:00      286.95
# 17  2012-01-27 16:00:00      289.87
# 18  2012-01-30 16:00:00      289.71
# 19  2012-01-31 16:00:00      291.71
# 20  2012-02-01 16:00:00      292.46
# 21  2012-02-02 16:00:00   Missing_1
# 22  2012-02-03 16:00:00      298.24
# 23  2012-02-06 16:00:00      305.11
# 24  2012-02-07 16:00:00    304.3903
# ...

# %%
mer_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   day_time  250 non-null    datetime64[ns]
#  1   level     250 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 4.0+ KB

# %%
mer_level=mer_level.replace(r'^[A-Za-z]',np.NaN,regex=True)

# %%
mer_level.isnull().sum()
# Out:
# day_time     0
# level       20
# dtype: int64

# %%
mer_level['level']=mer_level['level'].astype('float')

# %%
mer_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   day_time  250 non-null    datetime64[ns]
#  1   level     230 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.0 KB

# %%
mer_level.head()
# Out:
#              day_time   level
# 0 2012-01-03 16:00:00  333.74
# 1 2012-01-04 16:00:00  334.79
# 2 2012-01-05 16:00:00  331.65
# 3 2012-01-06 16:00:00  329.67
# 4 2012-01-09 16:00:00  323.18

# %%
mer_level['level'].plot(figsize=(12,4))
plt.legend()
plt.title('Mercury level')
plt.show()

# %%
mer_level=mer_level.assign(level_mean_imputation=mer_level.level.fillna(mer_level.level.mean()))

# %%
mer_level['level_mean_imputation'].plot(figsize=(12,4))
plt.legend()
plt.title('Mercury level MEAN')
plt.show()

# %%
#Linear Interpolation
mer_level=mer_level.assign(level_linear_interpolation=mer_level.level.interpolate(method='linear'))

# %%
mer_level['level_linear_interpolation'].plot(figsize=(12,4))
plt.legend()
plt.title('level_linear_interpolation')
plt.show()

# %%
mer_level
# Out:
#                day_time     level  level_mean_imputation  \
# 0   2012-01-03 16:00:00  333.7400             333.740000
# 1   2012-01-04 16:00:00  334.7900             334.790000
# 2   2012-01-05 16:00:00  331.6500             331.650000
# 3   2012-01-06 16:00:00  329.6700             329.670000
# 4   2012-01-09 16:00:00  323.1800             323.180000
# 5   2012-01-10 16:00:00  316.5800             316.580000
# 6   2012-01-11 16:00:00  314.3800             314.380000
# 7   2012-01-12 16:00:00  316.1300             316.130000
# 8   2012-01-13 16:00:00  313.1600             313.160000
# 9   2012-01-17 16:00:00  315.6700             315.670000
# 10  2012-01-18 16:00:00  316.6800             316.680000
# 11  2012-01-19 16:00:00  320.1700             320.170000
# 12  2012-01-20 16:00:00  295.2000             295.200000
# 13  2012-01-23 16:00:00  294.0400             294.040000
# 14  2012-01-24 16:00:00  293.5500             293.550000
# ...

# %%
final=round(mer_level[mer_level.level.isnull()]['level_linear_interpolation'],2)
final=pd.DataFrame(final)
l=final.level_linear_interpolation.to_list()

# %%
for i in l:
    print(i)
# Out:
# 295.35
# 304.73
# 309.18
# 308.11
# 307.14
# 323.65
# 315.65
# 313.62
# 286.91
# 326.3
# 337.54
# 339.9
# 343.49
# 342.82
# 360.0
# 372.77
# 372.16
# 342.16
# 334.99
# 332.42

# %%
import pandas as pd,numpy as np
    d=[]
    l=[]
    for i in readings:
        d.append(i.split("\t")[0])
        l.append(i.split("\t")[1])
    data=pd.DataFrame(list(zip(d,l)),columns=['day_time','level'])
    data['day_time']=pd.to_datetime(data['day_time'])
    data=data.replace(r'^[A-Za-z]',np.NaN,regex=True)
    data['level']=data['level'].astype('float')
    #linear interepolation
    data=data.assign(level_linear_interpolation=data.level.interpolate(method='linear'))
    final=round(data[data.level.isnull()]['level_linear_interpolation'],2)
    final=pd.DataFrame(final)
    final_level=final.level_linear_interpolation.to_list()
    for i in final_level:
        print(i)

# %%
from io import StringIO

s=str(data,'utf-8')
data = StringIO(s) 
df=pd.read_csv(data,header=None)

# %%
import pandas as pd

import datetime
import time
import requests
import io

# %%
url='https://jsonmock.hackerrank.com/api/stocks'
s = requests.get(url).content
companies = pd.read_csv(io.StringIO(s.decode('utf-8')),header=None)

# %%
df=companies.copy()

# %%
df
# Out:
#         0             1           2              3     \
# 0  {"page":1  per_page:500  total:2500  total_pages:5
#
#                              4             5             6            7     \
# 0  data:[{"date":"5-January-2000"  open:5265.09  high:5464.35  low:5184.48
#
#           8                         9             10            11    \
# 0  close:5357}  {"date":"6-January-2000"  open:5424.21  high:5489.86
#
#           12              13                        14            15    \
# 0  low:5391.33  close:5421.53}  {"date":"7-January-2000"  open:5358.28
#
#            16           17              18                         19    \
# 0  high:5463.25  low:5330.58  close:5414.48}  {"date":"11-January-2000"
#
#            20            21           22             23    \
# 0  open:5513.04  high:5537.69  low:5221.28  close:5296.3}
#
#                         24            25            26           27    \
# 0  {"date":"13-January-2000"  open:5568.64  high:5652.22  low:5430.81
# ...

# %%
len(df.columns)
# Out:
# 2504

# %%
l=[]
for i in range(4,len(df.columns)):
    l.append(df[i])

# %%
stock_new=pd.DataFrame(l)[0].to_list()

# %%
data=pd.DataFrame()

# %%
stock_new[0].split("{")[1].split(":")[1]
# Out:
# '"5-January-2000"'

# %%
open_list=[]
close_list=[]
low_list=[]
high_list=[]
date_list=[]

# %%
stock_new[i].split(":")[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-341-c75b9b07fe3f> in <module>
# ----> 1 stock_new[i].split(":")[0]
#
# IndexError: list index out of range

# %%
for i in range(0,len(stock_new)):
    if stock_new[i].split(":")[0]=='open':
        open_list.append(stock_new[i].split(":")[1])
    elif stock_new[i].split(":")[0]=='high':
        high_list.append(stock_new[i].split(":")[1])
    elif stock_new[i].split(":")[0]=='low':
        low_list.append(stock_new[i].split(":")[1])
    elif stock_new[i].split(":")[0]=='close':
        close_list.append(stock_new[i].split(":")[1])
    else:
        date_list.append(stock_new[i].split("{")[1].split(":")[1])

# %%
data=pd.DataFrame(list(zip(date_list,open_list,high_list,low_list,close_list)),columns=['date','open','high','low','close'])
data
# Out:
#                     date     open     high      low       close
# 0       "5-January-2000"  5265.09  5464.35  5184.48       5357}
# 1       "6-January-2000"  5424.21  5489.86  5391.33    5421.53}
# 2       "7-January-2000"  5358.28  5463.25  5330.58    5414.48}
# 3      "11-January-2000"  5513.04  5537.69  5221.28     5296.3}
# 4      "13-January-2000"  5568.64  5652.22  5430.81    5444.82}
# ..                   ...      ...      ...      ...         ...
# 495  "26-September-2002"  3011.42  3038.06  3011.42    3014.69}
# 496  "30-September-2002"  3029.56  3029.56  2988.43    2991.36}
# 497     "1-October-2002"  2976.04  2987.48  2948.75    2959.66}
# 498     "7-October-2002"  2939.18  2957.99  2927.47    2952.78}
# 499     "8-October-2002"  2954.29  2978.91  2953.95  2973.35}]}
#
# [500 rows x 5 columns]

# %%
data=data.apply(lambda x:x.str.replace('"',""))

# %%
data=data.apply(lambda x:x.str.replace('{',""))

# %%
data['close']=data['close'].apply(lambda x:x.replace("}",""))

# %%
data['date']=pd.to_datetime(data['date'])

# %%
data['close']=data['close'].apply(lambda x:x.replace("]",""))

# %%
data
# Out:
#           date     open     high      low    close
# 0   2000-01-05  5265.09  5464.35  5184.48     5357
# 1   2000-01-06  5424.21  5489.86  5391.33  5421.53
# 2   2000-01-07  5358.28  5463.25  5330.58  5414.48
# 3   2000-01-11  5513.04  5537.69  5221.28   5296.3
# 4   2000-01-13  5568.64  5652.22  5430.81  5444.82
# ..         ...      ...      ...      ...      ...
# 495 2002-09-26  3011.42  3038.06  3011.42  3014.69
# 496 2002-09-30  3029.56  3029.56  2988.43  2991.36
# 497 2002-10-01  2976.04  2987.48  2948.75  2959.66
# 498 2002-10-07  2939.18  2957.99  2927.47  2952.78
# 499 2002-10-08  2954.29  2978.91  2953.95  2973.35
#
# [500 rows x 5 columns]

# %%
data['open']=data['open'].astype('float')
data['high']=data['high'].astype('float')
data['low']=data['low'].astype('float')
data['close']=data['close'].astype('float')

# %%
data
# Out:
#           date     open     high      low    close
# 0   2000-01-05  5265.09  5464.35  5184.48  5357.00
# 1   2000-01-06  5424.21  5489.86  5391.33  5421.53
# 2   2000-01-07  5358.28  5463.25  5330.58  5414.48
# 3   2000-01-11  5513.04  5537.69  5221.28  5296.30
# 4   2000-01-13  5568.64  5652.22  5430.81  5444.82
# ..         ...      ...      ...      ...      ...
# 495 2002-09-26  3011.42  3038.06  3011.42  3014.69
# 496 2002-09-30  3029.56  3029.56  2988.43  2991.36
# 497 2002-10-01  2976.04  2987.48  2948.75  2959.66
# 498 2002-10-07  2939.18  2957.99  2927.47  2952.78
# 499 2002-10-08  2954.29  2978.91  2953.95  2973.35
#
# [500 rows x 5 columns]

# %%
stock_new[1].split(":")
# Out:
# ['open', '5265.09']

# %%
close_list
# Out:
# []

# %%
import pandas as pd , numpy as np , matplotlib.pyplot as plt, seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',300)

# %%
data=pd.read_csv('airline-passenger-traffic.csv',header=None)

# %%
data.columns=['Date','Passengers']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        144 non-null    object
#  1   Passengers  140 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.4+ KB

# %%
data['Date']=pd.to_datetime(data['Date'],format='%Y-%m')

# %%
data.head()
# Out:
#         Date  Passengers
# 0 1949-01-01       112.0
# 1 1949-02-01       118.0
# 2 1949-03-01       132.0
# 3 1949-04-01       129.0
# 4 1949-05-01       121.0

# %%
data.set_index('Date',inplace=True)

# %% [markdown]
# # Time series Staionary or Non - Stationary

# %% [markdown]
# ### Time Series Plot

# %%
data['Passengers'].plot(figsize=(12,4))
plt.legend()
plt.title('Airline Passenger ')
plt.show()

# %%
data=data.assign(Passenger_linear_interpolation=data.Passengers.interpolate(method='linear'))

# %%
data['Passengers']=data['Passenger_linear_interpolation']

# %%
data['Passengers'].plot(figsize=(12,4))
plt.legend()
plt.title('Airline Passenger ')
plt.show()

# %% [markdown]
# ## Augmented Dickey Fuller test (ADF)

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf_test=adfuller(data['Passengers'])

print('ADF Statistics: %f' %adf_test[0])
print('Critical value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistics: 0.894609
# Critical value @ 0.05: -2.88
# p-value: 0.993020

# %%
adf_test
# Out:
# (0.8946087940823844,
#  0.9930195647605924,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  993.7736365973918)

# %% [markdown]
# ## KPSS

# %%
from statsmodels.tsa.stattools import kpss

# %%
kpss_test=kpss(data['Passengers'])

# %%
print('KPSS Statistics: %f' %kpss_test[0])
print('Critical Value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value : %f' % kpss_test[1])
# Out:
# KPSS Statistics: 1.052050
# Critical Value @ 0.05: 0.46
# p-value : 0.010000

# %%
kpss_test
# Out:
# (1.0520501504573108,
#  0.01,
#  14,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# ## Box Cox Transformation

# %%
from scipy.stats import boxcox

# %%
data_boxcox=pd.Series(boxcox(data['Passengers'],lmbda=0),index=data.index)

# %%
data_boxcox
# Out:
# Date
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
# 1949-06-01    4.905275
# 1949-07-01    4.997212
# 1949-08-01    4.997212
# 1949-09-01    4.912655
# 1949-10-01    4.779123
# 1949-11-01    4.644391
# 1949-12-01    4.770685
# 1950-01-01    4.744932
# 1950-02-01    4.836282
# 1950-03-01    4.948760
# 1950-04-01    4.905275
# 1950-05-01    4.828314
# 1950-06-01    5.003946
# 1950-07-01    5.135798
# 1950-08-01    5.135798
# 1950-09-01    5.062595
# 1950-10-01    4.890349
# 1950-11-01    4.736198
# 1950-12-01    4.941642
# 1951-01-01    4.976734
# 1951-02-01    5.010635
# 1951-03-01    5.181784
# 1951-04-01    5.093750
# 1951-05-01    5.147494
# 1951-06-01    5.198497
# 1951-07-01    5.247024
# 1951-08-01    5.293305
# 1951-09-01    5.214936
# 1951-10-01    5.087596
# 1951-11-01    4.983607
# 1951-12-01    5.111988
# 1952-01-01    5.141664
# 1952-02-01    5.192957
# 1952-03-01    5.262690
# ...

# %%
data_boxcox.plot(figsize=(12,4),label='After BOx Cox Transformation')
plt.legend()
plt.title('Airline PAssenger BOXCOX ')
plt.show()

# %% [markdown]
# ## DIfferencing

# %%
data_boxcox_diff=pd.Series(data_boxcox-data_boxcox.shift(),index=data.index)

# %%
data_boxcox_diff.dropna(inplace=True)

# %%
plt.figure(figsize=(12,4))
plt.plot(data_boxcox_diff,label='After applying differencing')
plt.legend()
plt.title('Airline Passenger  after BOX COX   transform and DIFFERNCING ')
plt.show()

# %% [markdown]
# ## ADF Test

# %%
adf_test=adfuller(data_boxcox_diff)

# %%
print('ADF Statistics: %f' %adf_test[0])
print('Critical value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistics: -3.290114
# Critical value @ 0.05: -2.88
# p-value: 0.015326

# %% [markdown]
# ## KPSS

# %%
kpss_test=kpss(data_boxcox_diff)

# %%
print('KPSS Statistics: %f' %kpss_test[0])
print('Critical Value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value : %f' % kpss_test[1])
# Out:
# KPSS Statistics: 0.101871
# Critical Value @ 0.05: 0.46
# p-value : 0.100000

# %% [markdown]
# ## Auto Correlation function plot

# %%
from statsmodels.graphics.tsaplots import plot_acf
plt.figure(figsize=(12,4))
acf=plot_acf(data_boxcox_diff,ax=plt.gca(),lags=30)
plt.show()

# %% [markdown]
# ## Partial Auto Correlation Plot PACF

# %%
from statsmodels.graphics.tsaplots import plot_pacf

plt.figure(figsize=(12,4))
pacf=plot_pacf(data_boxcox_diff,ax=plt.gca(),lags=30)
plt.show()

# %% [markdown]
# ## Splitting into Training and Testing sets

# %%
train_len=120

# %%
train=data[:train_len]
test=data[train_len:]

# %%
train_data_boxcox=data_boxcox[:train_len]
test_data_boxcox=data_boxcox[train_len:]

train_data_boxcox_diff=data_boxcox_diff[:train_len-1]
test_data_boxcox_diff=data_boxcox_diff[train_len-1:]

# %% [markdown]
# ## AutoRegression Method

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(train_data_boxcox_diff,order=(1,0,0))
model_fit=model.fit()
print(model_fit.params)
# Out:
# const      0.009477
# ar.L1.y    0.183116
# dtype: float64

# %% [markdown]
# ## Recover original time series forecast

# %%
data
# Out:
#             Passengers  Passenger_linear_interpolation
# Date
# 1949-01-01       112.0                           112.0
# 1949-02-01       118.0                           118.0
# 1949-03-01       132.0                           132.0
# 1949-04-01       129.0                           129.0
# 1949-05-01       121.0                           121.0
# 1949-06-01       135.0                           135.0
# 1949-07-01       148.0                           148.0
# 1949-08-01       148.0                           148.0
# 1949-09-01       136.0                           136.0
# 1949-10-01       119.0                           119.0
# 1949-11-01       104.0                           104.0
# 1949-12-01       118.0                           118.0
# 1950-01-01       115.0                           115.0
# 1950-02-01       126.0                           126.0
# 1950-03-01       141.0                           141.0
# 1950-04-01       135.0                           135.0
# ...

# %%
y_hat_ar=data_boxcox_diff.copy()
y_hat_ar['ar_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_ar['ar_forecast_boxcox']=y_hat_ar['ar_forecast_boxcox_diff'].cumsum()
y_hat_ar['ar_forecast_boxcox']=y_hat_ar['ar_forecast_boxcox'].add(data_boxcox[0])
y_hat_ar['ar_forecast']=np.exp(y_hat_ar['ar_forecast_boxcox'])

# %% [markdown]
# ## Plot train test and forecast data

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'],label='Train')
plt.plot(test['Passengers'],label='Test')
plt.plot(y_hat_ar['ar_forecast'][test.index.min():],label='AR Model')
plt.legend()
plt.title('AR Method')
plt.show()

# %% [markdown]
# ## MAPE and RMSE

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse=np.sqrt(mean_squared_error(test['Passengers'],y_hat_ar['ar_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['Passengers']-y_hat_ar['ar_forecast'][test.index.min():])/test['Passengers'])*100,2)

# %%
result=pd.DataFrame({'Method':'AR Method','RMSE':[rmse],'MAPE':[mape]})
result
# Out:
#       Method       RMSE   MAPE
# 0  AR Method  93.386194  13.77

# %% [markdown]
# ## MOVING AVERAGE  Model

# %%
model=ARIMA(train_data_boxcox_diff,order=(0,0,1))
model_fit=model.fit()
print(model_fit.params)
# Out:
# const      0.009538
# ma.L1.y    0.266103
# dtype: float64

# %% [markdown]
# ## Recovering the original time series

# %%
y_hat_ma=data_boxcox_diff.copy()
y_hat_ma['ma_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_ma['ma_forecast_boxcox']=y_hat_ma['ma_forecast_boxcox_diff'].cumsum()
y_hat_ma['ma_forecast_boxcox']=y_hat_ma['ma_forecast_boxcox'].add(data_boxcox[0])
y_hat_ma['ma_forecast'] = np.exp(y_hat_ma['ma_forecast_boxcox'])

# %% [markdown]
# ## lot Train test and forecast time series

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'],label='Train')
plt.plot(test['Passengers'],label='Test')
plt.plot(y_hat_ma['ma_forecast'][test.index.min():],label='MA Model')
plt.legend()
plt.title('MA1 Method')
plt.show()

# %%
rmse=np.sqrt(mean_squared_error(test['Passengers'],y_hat_ma['ma_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['Passengers']-y_hat_ma['ma_forecast'][test.index.min():])/test['Passengers'])*100,2)
tempresult=pd.DataFrame({'Method':'Moving Average Method','RMSE':[rmse],'MAPE':[mape]})
result=pd.concat([result,tempresult])
result
# Out:
#                   Method       RMSE   MAPE
# 0              AR Method  93.386194  13.77
# 0  Moving Average Method  91.205517  13.39

# %% [markdown]
# ## AUTO REGRESSION MOVING AVERAGE
# # ARMA

# %%
model=ARIMA(train_data_boxcox_diff,order=(1,0,1))
model_fit=model.fit()
print(model_fit.params)
# Out:
# const      0.009624
# ar.L1.y   -0.527115
# ma.L1.y    0.798281
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_pacf

plt.figure(figsize=(12,4))
pacf=plot_pacf(train_data_boxcox_diff,ax=plt.gca(),lags=30)
plt.show()

plt.figure(figsize=(12,4))
acf=plot_acf(train_data_boxcox_diff,ax=plt.gca(),lags=30)
plt.show()

# %%
y_hat_arma=data_boxcox_diff.copy()
y_hat_arma['arma_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_arma['arma_forecast_boxcox']=y_hat_arma['arma_forecast_boxcox_diff'].cumsum()
y_hat_arma['arma_forecast_boxcox']=y_hat_arma['arma_forecast_boxcox'].add(data_boxcox[0])
y_hat_arma['arma_forecast']=np.exp(y_hat_arma['arma_forecast_boxcox'])

# %% [markdown]
# ## PLOT train test and forecast series

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'],label='Train')
plt.plot(test['Passengers'],label='Test')
plt.plot(y_hat_arma['arma_forecast'][test.index.min():],label='ARMA Model')
plt.legend()
plt.title('ARMA Method')
plt.show()

# %%
rmse=np.sqrt(mean_squared_error(test['Passengers'],y_hat_arma['arma_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['Passengers']-y_hat_arma['arma_forecast'][test.index.min():])/test['Passengers'])*100,2)
tempresult=pd.DataFrame({'Method':'Advance Regression Moving Average Method','RMSE':[rmse],'MAPE':[mape]})
result=pd.concat([result,tempresult])
result
# Out:
#                                      Method       RMSE   MAPE
# 0                                 AR Method  93.386194  13.77
# 0                     Moving Average Method  91.205517  13.39
# 0  Advance Regression Moving Average Method  88.879214  12.89

# %% [markdown]
# ## AUTO Regressive INTEGERATED MOVING AVERAGE ARIMA

# %%
# underlying Time series is Stationary - mean , variance is same
# ARIMA -  to remvoe trend - use differencing first step and later integerating later step 
# 3 parameters - p parmeters  - highest lag that we use for model observations
#                d - degree of differencing  to make series stationary 
#               q- Number of past error terms showuld be included 
    
# Zt - the difference series and made stationary .
# Zt= yt+1 - yt

# %%
model=ARIMA(train_data_boxcox,order=(1,1,1))
model_fit=model.fit()
print(model_fit.params)
# Out:
# const        0.009624
# ar.L1.D.y   -0.527115
# ma.L1.D.y    0.798281
# dtype: float64

# %% [markdown]
# ### Recover original time series forecast

# %%
y_hat_arima=data_boxcox_diff.copy()
y_hat_arima['arima_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_arima['arima_forecast_boxcox']=y_hat_arima['arima_forecast_boxcox_diff'].cumsum()
y_hat_arima['arima_forecast_boxcox']=y_hat_arima['arima_forecast_boxcox'].add(data_boxcox[0])
y_hat_arima['arima_forecast']=np.exp(y_hat_arima['arima_forecast_boxcox'])

# %% [markdown]
# ## PLot the train

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'],label='Train')
plt.plot(test['Passengers'],label='Test')
plt.plot(y_hat_arima['arima_forecast'][test.index.min():],label='ARIMA Model')
plt.legend()
plt.title('ARIMA Method')
plt.show()

# %% [markdown]
# ## RMSE and MAPE

# %%
rmse=np.sqrt(mean_squared_error(test['Passengers'],y_hat_arima['arima_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['Passengers']-y_hat_arima['arima_forecast'][test.index.min():])/test['Passengers'])*100,2)
tempresult=pd.DataFrame({'Method':'ARIMA Method','RMSE':[rmse],'MAPE':[mape]})
result=pd.concat([result,tempresult])
result
# Out:
#                                      Method       RMSE   MAPE
# 0                                 AR Method  93.386194  13.77
# 0                     Moving Average Method  91.205517  13.39
# 0  Advance Regression Moving Average Method  88.879214  12.89
# 0                              ARIMA Method  88.879214  12.89

# %% [markdown]
#  ## SARIMA Seasonal  Auto Regressive Integerated  Moving Average Method

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train_data_boxcox,order=(1,1,1),seasonal_order=(1,1,1,12))
model_fit=model.fit()
print(model_fit.params)
# Out:
# ar.L1       0.389984
# ma.L1      -0.680037
# ar.S.L12   -0.041410
# ma.S.L12   -0.516390
# sigma2      0.001408
# dtype: float64

# %% [markdown]
# ## Recover original TIme series forecast

# %%
y_hat_sarima=data_boxcox_diff.copy()
y_hat_sarima['sarima_forecast_boxcox']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_sarima['sarima_forecast']=np.exp(y_hat_sarima['sarima_forecast_boxcox'])

# %% [markdown]
# ## Plot the train test and forecast set

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'],label='Train')
plt.plot(test['Passengers'],label='Test')
plt.plot(y_hat_sarima['sarima_forecast'][test.index.min():],label='SARIMA Model')
plt.legend()
plt.title('SARIMA Method')
plt.show()

# %% [markdown]
# ## RMSA and MAPE

# %%
rmse=np.sqrt(mean_squared_error(test['Passengers'],y_hat_sarima['sarima_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['Passengers']-y_hat_sarima['sarima_forecast'][test.index.min():])/test['Passengers'])*100,2)
tempresult=pd.DataFrame({'Method':'SARIMA Method','RMSE':[rmse],'MAPE':[mape]})
result=pd.concat([result,tempresult])
result
# Out:
#                                      Method       RMSE   MAPE
# 0                                 AR Method  93.386194  13.77
# 0                     Moving Average Method  91.205517  13.39
# 0  Advance Regression Moving Average Method  88.879214  12.89
# 0                              ARIMA Method  88.879214  12.89
# 0                             SARIMA Method  37.602721   7.38

# %% [markdown]
# ## SARIMAX - SARIMA with EXOGENOUS Variables

# %%
promo=pd.read_csv('promotion.csv',header=None)
promo.columns=['Month','Event']
promo['Month']=pd.to_datetime(promo['Month'],format='%Y-%m')
promo.set_index('Month',inplace=True)

# %%
promo.head()
# Out:
#             Event
# Month
# 1949-01-01      0
# 1949-02-01      0
# 1949-03-01      0
# 1949-04-01      0
# 1949-05-01      0

# %%
promo_train=promo[:train_len]
promo_test=promo[train_len:]

# %%
model=SARIMAX(train_data_boxcox,order=(1,1,1),seasonal_order=(1,1,1,12),exog=promo_train)
model_fit=model.fit()
print(model_fit.params)
# Out:
# Event       0.034409
# ar.L1       0.484559
# ma.L1      -0.746240
# ar.S.L12   -0.062949
# ma.S.L12   -0.559467
# sigma2      0.001334
# dtype: float64

# %% [markdown]
# ## Getting original data

# %%
y_hat_sarimax=data_boxcox_diff.copy()
y_hat_sarimax['sarimax_forecast_boxcox']=model_fit.predict(test.index.min(),test.index.max(),exog=promo_test)
y_hat_sarimax['sarimax_forecast']=np.exp(y_hat_sarimax['sarimax_forecast_boxcox'])

# %% [markdown]
# ## Plot train test and forecast

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'],label='Train')
plt.plot(test['Passengers'],label='Test')
plt.plot(y_hat_sarimax['sarimax_forecast'][test.index.min():],label='SARIMAX Model')
plt.legend()
plt.title('SARIMAX Method')
plt.show()

# %% [markdown]
# ## RMSE and MAPE

# %%
rmse=np.sqrt(mean_squared_error(test['Passengers'],y_hat_sarimax['sarimax_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['Passengers']-y_hat_sarimax['sarimax_forecast'][test.index.min():])/test['Passengers'])*100,2)
tempresult=pd.DataFrame({'Method':'SARIMAX Method','RMSE':[rmse],'MAPE':[mape]})
result=pd.concat([result,tempresult])
result
# Out:
#                                      Method       RMSE   MAPE
# 0                                 AR Method  93.386194  13.77
# 0                     Moving Average Method  91.205517  13.39
# 0  Advance Regression Moving Average Method  88.879214  12.89
# 0                              ARIMA Method  88.879214  12.89
# 0                             SARIMA Method  37.602721   7.38
# 0                            SARIMAX Method  26.444129   4.61

# %% [markdown]
# #  <font color='GREEN'>UNRATE graded question

# %%
unr=pd.read_csv('UNRATE.csv',header=None)
unr.columns=['Date','UNRATE']
unr['Date']=pd.to_datetime(unr['Date'],format='%d-%m-%Y')
unr.set_index('Date',inplace=True)
unr.head()
# Out:
#             UNRATE
# Date
# 1948-01-01     3.4
# 1948-02-01     3.8
# 1948-03-01     4.0
# 1948-04-01     3.9
# 1948-05-01     3.5

# %%
train_len=612
train=unr[:train_len]
test=unr[train_len:]

# %%
train.shape
# Out:
# (612, 1)

# %%
test.shape
# Out:
# (255, 1)

# %%
plt.figure(figsize=[12,4])
plt.plot(unr['UNRATE'])

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize']=12,8
decomposition=sm.tsa.seasonal_decompose(unr.UNRATE,model='additive')
fig=decomposition.plot()
plt.show()

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize']=12,8
decomposition=sm.tsa.seasonal_decompose(unr.UNRATE,model='multiplicative')
fig=decomposition.plot()
plt.show()

# %% [markdown]
# ## ADF Test

# %%
from statsmodels.tsa.stattools import adfuller
adf_test=adfuller(unr['UNRATE'])

print('ADF Statistics: %f' %adf_test[0])
print('Critical value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistics: -3.143963
# Critical value @ 0.05: -2.86
# p-value: 0.023466

# %% [markdown]
# ## KPSS Test

# %%
from statsmodels.tsa.stattools import kpss
kpss_test=kpss(unr['UNRATE'])

print('KPSS Statistics: %f' %kpss_test[0])
print('Critical value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])
# Out:
# KPSS Statistics: 0.464446
# Critical value @ 0.05: 0.46
# p-value: 0.049674

# %% [markdown]
# ## BOXCOX Transformation

# %%
from scipy.stats import boxcox

# %%
data_boxcox=pd.Series(boxcox(unr['UNRATE'],lmbda=0),index=unr.index)

# %%
data_boxcox
# Out:
# Date
# 1948-01-01    1.223775
# 1948-02-01    1.335001
# 1948-03-01    1.386294
# 1948-04-01    1.360977
# 1948-05-01    1.252763
#                 ...
# 2019-11-01    1.252763
# 2019-12-01    1.252763
# 2020-01-01    1.280934
# 2020-02-01    1.252763
# 2020-03-01    1.481605
# Length: 867, dtype: float64

# %%
plt.plot(unr)

# %%
plt.plot(data_boxcox)

# %%
data_boxcox.shape
# Out:
# (867,)

# %%
data_boxcox_diff=pd.Series(data_boxcox-data_boxcox.shift(),index=unr.index)

# %%
data_boxcox_diff
# Out:
# Date
# 1948-01-01         NaN
# 1948-02-01    0.111226
# 1948-03-01    0.051293
# 1948-04-01   -0.025318
# 1948-05-01   -0.108214
#                 ...
# 2019-11-01   -0.028171
# 2019-12-01    0.000000
# 2020-01-01    0.028171
# 2020-02-01   -0.028171
# 2020-03-01    0.228842
# Length: 867, dtype: float64

# %%
data_boxcox_diff.dropna(inplace=True)

# %%
plt.plot(data_boxcox_diff)

# %%
data_boxcox_diff.shape
# Out:
# (866,)

# %%
from statsmodels.tsa.stattools import kpss
kpss_test=kpss(data_boxcox)

print('KPSS Statistics: %f' %kpss_test[0])
print('Critical value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])
# Out:
# KPSS Statistics: 0.526494
# Critical value @ 0.05: 0.46
# p-value: 0.035699

# %%
from statsmodels.tsa.stattools import adfuller
adf_test=adfuller(data_boxcox)

print('ADF Statistics: %f' %adf_test[0])
print('Critical value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistics: -3.225377
# Critical value @ 0.05: -2.86
# p-value: 0.018562

# %%
from statsmodels.tsa.stattools import kpss
kpss_test=kpss(data_boxcox_diff)

print('KPSS Statistics: %f' %kpss_test[0])
print('Critical value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])
# Out:
# KPSS Statistics: 0.062761
# Critical value @ 0.05: 0.46
# p-value: 0.100000

# %%
from statsmodels.tsa.stattools import adfuller
adf_test=adfuller(data_boxcox_diff)

print('ADF Statistics: %f' %adf_test[0])
print('Critical value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistics: -8.918955
# Critical value @ 0.05: -2.86
# p-value: 0.000000

# %% [markdown]
# ## SPlitting data into training AND testing period

# %%
train_data_boxcox=data_boxcox[:train_len]
test_data_boxcox=data_boxcox[train_len:]
train_data_boxcox_diff=data_boxcox_diff[:train_len-1]
test_data_boxcox_diff=data_boxcox_diff[train_len-1:]

# %%
train_data_boxcox.shape
# Out:
# (612,)

# %%
train_data_boxcox_diff.shape
# Out:
# (611,)

# %%
test_data_boxcox_diff.shape
# Out:
# (255,)

# %%
test_data_boxcox.shape
# Out:
# (255,)

# %% [markdown]
# # AR

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(train_data_boxcox_diff,order=(12,0,0))
model_fit=model.fit()
model_fit.params
# Out:
# const       0.000466
# ar.L1.y     0.060691
# ar.L2.y     0.161198
# ar.L3.y     0.118645
# ar.L4.y     0.090456
# ar.L5.y     0.107079
# ar.L6.y     0.008286
# ar.L7.y    -0.029412
# ar.L8.y     0.032450
# ar.L9.y     0.006198
# ar.L10.y   -0.124660
# ar.L11.y    0.047124
# ar.L12.y   -0.148533
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_pacf

plt.figure(figsize=(12,4))
pacf=plot_pacf(train_data_boxcox_diff,ax=plt.gca(),lags=30)
plt.show()

plt.figure(figsize=(12,4))
acf=plot_acf(train_data_boxcox_diff,ax=plt.gca(),lags=30)
plt.show()

# %% [markdown]
# ## Recover original time series

# %%
y_hat_ar=data_boxcox_diff.copy()
y_hat_ar['ar_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_ar['ar_forecast_boxcox']=y_hat_ar['ar_forecast_boxcox_diff'].cumsum()
y_hat_ar['ar_forecast_boxcox']=y_hat_ar['ar_forecast_boxcox'].add(data_boxcox[0])

# %%
y_hat_ar['ar_forecast']=np.exp(y_hat_ar['ar_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot(train['UNRATE'],label='Train')
plt.plot(test['UNRATE'],label='Test')
plt.plot(y_hat_ar['ar_forecast'][test.index.min():],label='AR Model')
plt.legend()
plt.title('AR Method')
plt.show()

# %% [markdown]
# ## AR RMSE and KPSS

# %%
rmse=np.sqrt(mean_squared_error(test['UNRATE'],y_hat_ar['ar_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['UNRATE']-y_hat_ar['ar_forecast'][test.index.min():])/test['UNRATE'])*100,2)
grad_result=pd.DataFrame({'Method':'AR Method','RMSE':[rmse],'MAPE':[mape]})
grad_result
# Out:
#       Method      RMSE   MAPE
# 0  AR Method  1.830592  23.62

# %%
hat=pd.DataFrame(y_hat_ar).loc['ar_forecast'][:]

# %%
pd.set_option('display.max_rows',300)

# %%
pd.set_option('display.max_columns',300)

# %%
hat.to_list()
# Out:
# [1948-02-01    3.901819
#  1948-03-01    3.960923
#  1948-04-01    4.082803
#  1948-05-01    4.188015
#  1948-06-01    4.210204
#                  ...
#  2019-11-01    5.791531
#  2019-12-01    5.794232
#  2020-01-01    5.796935
#  2020-02-01    5.799639
#  2020-03-01    5.802344
#  Freq: MS, Length: 866, dtype: float64]

# %% [markdown]
# # MOVING AVERAGE

# %%
model=ARIMA(data_boxcox_diff,order=(0,0,5))
model_fit=model.fit()
print(model_fit.params)
# Out:
# const      0.000527
# ma.L1.y    0.035632
# ma.L2.y    0.187062
# ma.L3.y    0.118078
# ma.L4.y    0.085487
# ma.L5.y    0.167566
# dtype: float64

# %% [markdown]
# ## Recovering Original Model

# %%
y_hat_ma=data_boxcox_diff.copy()
y_hat_ma['ma_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_ma['ma_forecast_boxcox']=y_hat_ma['ma_forecast_boxcox_diff'].cumsum()
y_hat_ma['ma_forecast_boxcox']=y_hat_ma['ma_forecast_boxcox'].add(data_boxcox[0])
y_hat_ma['ma_forecast']=np.exp(y_hat_ma['ma_forecast_boxcox'])

# %%
plt.plot(train['UNRATE'])
plt.plot(test['UNRATE'])
plt.plot(y_hat_ma['ma_forecast'][test.index.min():])

# %%
plt.figure(figsize=(12,4))
plt.plot(train['UNRATE'],label='Train')
plt.plot(test['UNRATE'],label='Test')
plt.plot(y_hat_ma['ma_forecast'][test.index.min():],label='MA Model')
plt.legend()
plt.title('MA Method')
plt.show()

# %%
rmse=np.sqrt(mean_squared_error(test['UNRATE'],y_hat_ma['ma_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['UNRATE']-y_hat_ma['ma_forecast'][test.index.min():])/test['UNRATE'])*100,2)
tempresult=pd.DataFrame({'Method':'MA Method','RMSE':[rmse],'MAPE':[mape]})
#grad_result=pd.concat([grad_result,tempresult])

# %%
tempresult
# Out:
#       Method      RMSE   MAPE
# 0  MA Method  1.176779  18.84

# %%
y_hat_ma.to_list()
# Out:
# [0.11122563511022432,
#  0.05129329438755059,
#  -0.025317807984289953,
#  -0.10821358464023256,
#  0.02817087696669618,
#  0.0,
#  0.08004270767353638,
#  -0.02597548640326064,
#  -0.02666824708216109,
#  0.02666824708216109,
#  0.05129329438755059,
#  0.07232066157962613,
#  0.08894748601649627,
#  0.06187540371808731,
#  0.05826890812397578,
#  0.1405819506211894,
#  0.016260520871780537,
#  0.0775582343458745,
#  0.01481508578514057,
#  -0.029852963149681333,
#  0.17979311044059632,
#  -0.21056476910734978,
#  0.030771658666753465,
#  -0.015267472130788384,
#  -0.015504186535965081,
#  -0.015748356968139365,
#  -0.08269171584511326,
#  -0.05310982531394837,
#  -0.01834913866819643,
#  -0.07696104113612856,
#  -0.10536051565782611,
#  -0.022472855852058604,
#  -0.04652001563489283,
#  0.0,
#  0.023530497410193973,
#  -0.15028220304933781,
#  -0.08455738802806323,
#  0.0,
#  -0.09237332013101507,
#  -0.03278982282299081,
#  0.06453852113757108,
#  -0.03174869831458027,
#  0.0,
# ...

# %% [markdown]
# ## ARIMA

# %%
model=ARIMA(train_data_boxcox,order=(12,1,5))
model_fit=model.fit()
print(model_fit.params)
# Out:
# const         0.000459
# ar.L1.D.y    -0.273282
# ar.L2.D.y     0.780065
# ar.L3.D.y     0.596082
# ar.L4.D.y    -0.520689
# ar.L5.D.y    -0.686251
# ar.L6.D.y     0.062530
# ar.L7.D.y     0.052221
# ar.L8.D.y     0.098916
# ar.L9.D.y     0.168183
# ar.L10.D.y   -0.039236
# ar.L11.D.y   -0.038662
# ar.L12.D.y   -0.047073
# ma.L1.D.y     0.302919
# ma.L2.D.y    -0.615667
# ma.L3.D.y    -0.445546
# ma.L4.D.y     0.575664
# ma.L5.D.y     0.750619
# dtype: float64

# %%
y_hat_arima=data_boxcox_diff.copy()
y_hat_arima['arima_forecast_boxcox_diff']=model_fit.predict(data_boxcox_diff.index.min(),data_boxcox_diff.index.max())
y_hat_arima['arima_forecast_boxcox']=y_hat_arima['arima_forecast_boxcox_diff'].cumsum()
y_hat_arima['arima_forecast_boxcox']=y_hat_arima['arima_forecast_boxcox'].add(data_boxcox[0])
y_hat_arima['arima_forecast']=np.exp(y_hat_arima['arima_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot(train['UNRATE'],label='Train')
plt.plot(test['UNRATE'],label='Test')
plt.plot(y_hat_arima['arima_forecast'][test.index.min():],label='ARIMA Model')
plt.legend()
plt.title('ARIMA Method')
plt.show()

# %%
rmse=np.sqrt(mean_squared_error(test['UNRATE'],y_hat_arima['arima_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['UNRATE']-y_hat_arima['arima_forecast'][test.index.min():])/test['UNRATE'])*100,2)
tempresult=pd.DataFrame({'Method':'ARIMA Method','RMSE':[rmse],'MAPE':[mape]})
#tempresult=pd.concat([result,tempresult])

# %%
tempresult
# Out:
#          Method      RMSE   MAPE
# 0  ARIMA Method  1.845289  23.23

# %% [markdown]
# # SARIMA

# %%
model=SARIMAX(train_data_boxcox,order=(2,1,4),seasonal_order=(2,1,4,12))
model_fit=model.fit()
print(model_fit.params)
# Out:
# ar.L1       0.689209
# ar.L2       0.007679
# ma.L1      -0.704995
# ma.L2       0.173034
# ma.L3       0.027119
# ma.L4       0.053082
# ar.S.L12   -0.739900
# ar.S.L24   -0.013953
# ma.S.L12   -0.471526
# ma.S.L24   -0.826523
# ma.S.L36    0.182914
# ma.S.L48    0.146540
# sigma2      0.001487
# dtype: float64

# %%
y_hat_sarimax=data_boxcox_diff.copy()
y_hat_sarimax['sarimax_forecast_boxcox']=model_fit.predict(test.index.min(),test.index.max())
y_hat_sarimax['sarimax_forecast']=np.exp(y_hat_sarimax['sarimax_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot(train['UNRATE'],label='Train')
plt.plot(test['UNRATE'],label='Test')
plt.plot(y_hat_sarimax['sarimax_forecast'][test.index.min():],label='SARIMAX Model')
plt.legend()
plt.title('SARIMAX Method')
plt.show()

# %%
rmse=np.sqrt(mean_squared_error(test['UNRATE'],y_hat_sarimax['sarimax_forecast'][test.index.min():]))
mape=np.round(np.mean(np.abs(test['UNRATE']-y_hat_sarimax['sarimax_forecast'][test.index.min():])/test['UNRATE'])*100,2)
tempresult=pd.DataFrame({'Method':'SARIMAX Method','RMSE':[rmse],'MAPE':[mape]})
tempresult
# Out:
#            Method      RMSE   MAPE
# 0  SARIMAX Method  2.147532  21.15
